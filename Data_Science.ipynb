# %% [markdown]
# <a href="https://colab.research.google.com/github/RomiPawar/Python/blob/main/Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_excel("/content/drive/MyDrive/Data Sets/DS - Assignment Part 1 data set.xlsx")

# %%
data.head(15)
# Out:
#     Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0        2012.916667       32.0                                  84.87882
# 1        2012.916667       19.5                                 306.59470
# 2        2013.583333       13.3                                 561.98450
# 3        2013.500000       13.3                                 561.98450
# 4        2012.833333        5.0                                 390.56840
# 5        2012.666667        7.1                                2175.03000
# 6        2012.666667       34.5                                 623.47310
# 7        2013.416667       20.3                                 287.60250
# 8        2013.500000       31.7                                5512.03800
# 9        2013.416667       17.9                                1783.18000
# 10       2013.083333       34.8                                 405.21340
# 11       2013.333333        6.3                                  90.45606
# ...

# %%
data.describe()
# Out:
#        Transaction date   House Age  Distance from nearest Metro station (km)  \
# count        414.000000  414.000000                                414.000000
# mean        2013.148953   17.712560                               1083.885689
# std            0.281995   11.392485                               1262.109595
# min         2012.666667    0.000000                                 23.382840
# 25%         2012.916667    9.025000                                289.324800
# 50%         2013.166667   16.100000                                492.231300
# 75%         2013.416667   28.150000                               1454.279000
# max         2013.583333   43.800000                               6488.021000
#
#        Number of convenience stores    latitude   longitude  \
# count                    414.000000  414.000000  414.000000
# mean                       4.094203   24.969030  121.533361
# std                        2.945562    0.012410    0.015347
# ...

# %%
# Rename all column names in short format
data.columns = ['Transaction_date', 'House_Age', 'Distance_from_nearest_Metro_station_(km)', 'Number_of_convenience_stores', 'latitude',
              'longitude', 'Number_of_bedrooms', 'House_size_(sqft)', 'House_price_of_unit_area']

# %%
#Rename to view the column name
data1=data.columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Transaction date                          414 non-null    float64
#  1   House Age                                 414 non-null    float64
#  2   Distance from nearest Metro station (km)  414 non-null    float64
#  3   Number of convenience stores              414 non-null    int64
#  4   latitude                                  414 non-null    float64
#  5   longitude                                 414 non-null    float64
#  6   Number of bedrooms                        414 non-null    int64
#  7   House size (sqft)                         414 non-null    int64
#  8   House price of unit area                  414 non-null    float64
# dtypes: float64(6), int64(3)
# memory usage: 29.2 KB

# %%
plt.figure(figsize=(9,9))
sns.jointplot(x=data.latitude.values, y=data.longitude.values, size=10)
plt.ylabel('Longitude', fontsize=10)
plt.xlabel('Latitude', fontsize=10)
plt.show()
sns.despine
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
fig = plt.figure(figsize = (10,6))
sns.barplot(x = 'House price of unit area', y = 'House size (sqft)', data = data)

# %%
plt.figure(figsize=(10,7))
plt.scatter('House price of unit area', 'House size (sqft)', data=data)
plt.scatter('House price of unit area', 'House size (sqft)', data=data)

plt.xlabel("Price")
plt.ylabel("Sqft")
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter('House price of unit area', 'longitude', data=data)
plt.scatter('House price of unit area', 'longitude', data=data)

plt.xlabel("Price")
plt.ylabel("Location of area")
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter('House price of unit area', 'latitude', data=data)
plt.scatter('House price of unit area', 'latitude', data=data)

plt.xlabel("Price")
plt.ylabel("Latitude")
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter('House price of unit area', 'House Age', data=data)
plt.scatter('House price of unit area', 'House Age', data=data)

plt.xlabel("Price")
plt.ylabel("House Age")
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter('House price of unit area', 'Distance from nearest Metro station (km)', data=data)
plt.scatter('House price of unit area', 'Distance from nearest Metro station (km)', data=data)

plt.xlabel("Price")
plt.ylabel("Distance")
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter('House price of unit area', 'Number of convenience stores', data=data)
plt.scatter('House price of unit area', 'Number of convenience stores', data=data)

plt.xlabel("Price")
plt.ylabel("No. of Stores")
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter('House price of unit area', 'Number of bedrooms', data=data)
plt.scatter('House price of unit area', 'Number of bedrooms', data=data)

plt.xlabel("Price")
plt.ylabel("Number of bedrooms ")
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.scatter('House price of unit area', 'Transaction date', data=data)
plt.scatter('House price of unit area', 'Transaction date', data=data)

plt.xlabel("Price")
plt.ylabel("Transaction date")
plt.show()

# %%
print(data.Transaction_date)
# Out:
# 0      2012.916667
# 1      2012.916667
# 2      2013.583333
# 3      2013.500000
# 4      2012.833333
#           ...
# 409    2013.000000
# 410    2012.666667
# 411    2013.250000
# 412    2013.000000
# 413    2013.500000
# Name: Transaction_date, Length: 414, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
labels = data['House_price_of_unit_area']
conv_dates = [1 if values == 2014 else 0 for values in data.Transaction_date]
data['Transactiondate'] = conv_dates
train1 = data.drop(['House_price_of_unit_area'],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(train1, labels, test_size = 0.10, random_state = 2)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test,y_test)
# Out:
# 0.6624623923995568

# %% [markdown]
# Finally, after fitting the data to the model one can check the score of the imported data i.e., prediction. in this case the prediction is **66.24%**
